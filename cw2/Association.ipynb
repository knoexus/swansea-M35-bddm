# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./Dataset/House_Price_Dataset.csv')
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method  Seller  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Latitude  Longitude             RegionName  \
# 0        NaN  Yarra City Council -37.8014   144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council -37.7996   144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council -37.8079   144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council -37.8114   145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council -37.8093   144.9944  Northern Metropolitan
#
#   PropertyCount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
np.unique(data["Seller"]).size
# Out:
# 388

# %%
seller_gr = data.groupby(['Seller']).size().sort_values(ascending=False).reset_index(name='counts')
seller_gr.head()
# Out:
#           Seller  counts
# 0         Jellis    3359
# 1         Nelson    3236
# 2          Barry    3235
# 3  hockingstuart    2623
# 4       Marshall    2027

# %%
cut = data[["Method", "Seller", "RegionName"]]
cut = cut[(~cut['Method'].isnull()) & (~cut['Seller'].isnull()) & (~cut['RegionName'].isnull())]
cut.head()
# Out:
#   Method  Seller             RegionName
# 0     SS  Jellis  Northern Metropolitan
# 1      S  Biggin  Northern Metropolitan
# 2      S  Biggin  Northern Metropolitan
# 3     VB  Rounds  Northern Metropolitan
# 4     SP  Biggin  Northern Metropolitan

# %%
print(np.unique(cut["Method"]))
# Out:
# ['PI' 'PN' 'S' 'SA' 'SN' 'SP' 'SS' 'VB' 'W']

# %%
cut["Method"] = cut["Method"].apply(lambda x: 'S' if x.startswith('S') else 'N')

# %%
methods = [frozenset(x) for x in np.unique(cut["Method"])]
methods
# Out:
# [frozenset({'N'}), frozenset({'S'})]

# %%
np_cut = cut.to_numpy()

# %%
te = TransactionEncoder()
te_ary = te.fit(np_cut).transform(np_cut)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#    @Realty      A   AIME    ASL  Abercromby's    Ace  Airport   Alex  \
# 0    False  False  False  False         False  False    False  False
# 1    False  False  False  False         False  False    False  False
# 2    False  False  False  False         False  False    False  False
# 3    False  False  False  False         False  False    False  False
# 4    False  False  False  False         False  False    False  False
#
#    Alexkarbon  Allan  ...  hockingstuart/Marshall  hockingstuart/Sweeney  \
# 0       False  False  ...                   False                  False
# 1       False  False  ...                   False                  False
# 2       False  False  ...                   False                  False
# 3       False  False  ...                   False                  False
# 4       False  False  ...                   False                  False
#
#    hockingstuart/Village  hockingstuart/hockingstuart  iHomes   iOne  \
# 0                  False                        False   False  False
# 1                  False                        False   False  False
# 2                  False                        False   False  False
# 3                  False                        False   False  False
# 4                  False                        False   False  False
#
#    iProperty  iSell  iTRAK  voglwalpole
# 0      False  False  False        False
# 1      False  False  False        False
# 2      False  False  False        False
# 3      False  False  False        False
# 4      False  False  False        False
#
# [5 rows x 398 columns]

# %%
res = fpgrowth(df, min_support=0.01, use_colnames=True, max_len=3)

# %%
res.head()
# Out:
#     support                 itemsets
# 0  0.757904                      (S)
# 1  0.274201  (Northern Metropolitan)
# 2  0.096345                 (Jellis)
# 3  0.025736                 (Biggin)
# 4  0.242096                      (N)

# %%
res[res['itemsets'].map(len) == 3].sort_values(by=['support'], ascending=False)
# Out:
#      support                                   itemsets
# 47  0.043869         (Northern Metropolitan, Nelson, S)
# 54  0.041516       (S, Marshall, Southern Metropolitan)
# 39  0.036495         (Southern Metropolitan, Jellis, S)
# 87  0.032278         (Southern Metropolitan, Buxton, S)
# 62  0.029150  (Southern Metropolitan, S, hockingstuart)
# 74  0.024101          (Northern Metropolitan, S, Barry)
# 73  0.023039           (S, Barry, Western Metropolitan)
# 37  0.022006         (Northern Metropolitan, Jellis, S)
# 49  0.019998          (Nelson, S, Western Metropolitan)
# 81  0.018563            (Northern Metropolitan, Ray, S)
# 75  0.016555           (Eastern Metropolitan, S, Barry)
# 55  0.014374       (Southern Metropolitan, Marshall, N)
# 38  0.012940         (Southern Metropolitan, Jellis, N)
# 48  0.012251         (Northern Metropolitan, Nelson, N)
# 86  0.011505         (Southern Metropolitan, Buxton, N)
# 63  0.010673   (S, hockingstuart, Western Metropolitan)
# 97  0.010558             (Jas, S, Western Metropolitan)
# 61  0.010530  (Northern Metropolitan, S, hockingstuart)
# 93  0.010185           (Eastern Metropolitan, S, Miles)

# %%
ar = association_rules(res, metric="support", min_threshold=0.01)

# %%
ar.head()
# Out:
#                antecedents              consequents  antecedent support  \
# 0  (Northern Metropolitan)                      (S)            0.274201
# 1                      (S)  (Northern Metropolitan)            0.757904
# 2                 (Jellis)                      (S)            0.096345
# 3                      (S)                 (Jellis)            0.757904
# 4  (Northern Metropolitan)                 (Jellis)            0.274201
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.757904  0.215011    0.784137  1.034612  0.007193    1.121526
# 1            0.274201  0.215011    0.283692  1.034612  0.007193    1.013250
# 2            0.757904  0.071269    0.739726  0.976015 -0.001751    0.930157
# 3            0.096345  0.071269    0.094034  0.976015 -0.001751    0.997449
# 4            0.096345  0.029064    0.105996  1.100170  0.002646    1.010795

# %%
ar[(ar['antecedents'].map(len) == 2) 
       & ((ar['consequents'].map(len) == 1) 
            & (ar['consequents'].isin(methods)))
  ].sort_values(by=['confidence', 'lift'], ascending=False
  ).head(100)
# Out:
#                                 antecedents consequents  antecedent support  \
# 156            (Northern Metropolitan, Ray)         (S)            0.022723
# 193           (Eastern Metropolitan, Miles)         (S)            0.012509
# 205             (Jas, Western Metropolitan)         (S)            0.013026
# 135          (Northern Metropolitan, Barry)         (S)            0.030269
# 106   (hockingstuart, Western Metropolitan)         (S)            0.013485
# 130           (Barry, Western Metropolitan)         (S)            0.029408
# 44          (Northern Metropolitan, Nelson)         (S)            0.056120
# 12          (Northern Metropolitan, Jellis)         (S)            0.029064
# 99   (Southern Metropolitan, hockingstuart)         (S)            0.038503
# 93   (Northern Metropolitan, hockingstuart)         (S)            0.014030
# 72        (Southern Metropolitan, Marshall)         (S)            0.055890
# 57           (Nelson, Western Metropolitan)         (S)            0.027027
# 141           (Eastern Metropolitan, Barry)         (S)            0.022379
# 24          (Southern Metropolitan, Jellis)         (S)            0.049435
# 176         (Southern Metropolitan, Buxton)         (S)            0.043783
# 170         (Southern Metropolitan, Buxton)         (N)            0.043783
# 18          (Southern Metropolitan, Jellis)         (N)            0.049435
# 76        (Southern Metropolitan, Marshall)         (N)            0.055890
# 50          (Northern Metropolitan, Nelson)         (N)            0.056120
#
#      consequent support   support  confidence      lift  leverage  conviction
# 156            0.757904  0.018563    0.816919  1.077866  0.001341    1.322343
# 193            0.757904  0.010185    0.814220  1.074305  0.000704    1.303132
# 205            0.757904  0.010558    0.810573  1.069492  0.000686    1.278040
# 135            0.757904  0.024101    0.796209  1.050540  0.001159    1.187957
# 106            0.757904  0.010673    0.791489  1.044313  0.000453    1.161071
# 130            0.757904  0.023039    0.783415  1.033659  0.000750    1.117784
# 44             0.757904  0.043869    0.781697  1.031393  0.001335    1.108991
# 12             0.757904  0.022006    0.757157  0.999014 -0.000022    0.996922
# 99             0.757904  0.029150    0.757079  0.998911 -0.000032    0.996602
# 93             0.757904  0.010530    0.750511  0.990245 -0.000104    0.970367
# 72             0.757904  0.041516    0.742813  0.980088 -0.000843    0.941322
# 57             0.757904  0.019998    0.739915  0.976264 -0.000486    0.930833
# 141            0.757904  0.016555    0.739744  0.976038 -0.000406    0.930220
# 24             0.757904  0.036495    0.738247  0.974064 -0.000972    0.924902
# 176            0.757904  0.032278    0.737221  0.972710 -0.000906    0.921291
# 170            0.242096  0.011505    0.262779  1.085433  0.000906    1.028055
# 18             0.242096  0.012940    0.261753  1.081196  0.000972    1.026627
# 76             0.242096  0.014374    0.257187  1.062336  0.000843    1.020316
# 50             0.242096  0.012251    0.218303  0.901721 -0.001335    0.969562
