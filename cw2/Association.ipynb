# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./Dataset/House_Price_Dataset.csv')
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method  Seller  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Latitude  Longitude             RegionName  \
# 0        NaN  Yarra City Council -37.8014   144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council -37.7996   144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council -37.8079   144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council -37.8114   145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council -37.8093   144.9944  Northern Metropolitan
#
#   PropertyCount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
np.unique(data["Seller"]).size
# Out:
# 388

# %%
seller_gr = data.groupby(['Seller']).size().sort_values(ascending=False).reset_index(name='counts')
seller_gr.head()
# Out:
#           Seller  counts
# 0         Jellis    3359
# 1         Nelson    3236
# 2          Barry    3235
# 3  hockingstuart    2623
# 4       Marshall    2027

# %%
cut = data[["Method", "Seller", "RegionName"]]
cut = cut[(~cut['Method'].isnull()) & (~cut['Seller'].isnull()) & (~cut['RegionName'].isnull())]
cut.head()
# Out:
#   Method  Seller             RegionName
# 0     SS  Jellis  Northern Metropolitan
# 1      S  Biggin  Northern Metropolitan
# 2      S  Biggin  Northern Metropolitan
# 3     VB  Rounds  Northern Metropolitan
# 4     SP  Biggin  Northern Metropolitan

# %%
print(np.unique(cut["Method"]))
# Out:
# ['PI' 'PN' 'S' 'SA' 'SN' 'SP' 'SS' 'VB' 'W']

# %%
cut["Method"] = cut["Method"].apply(lambda x: 'S' if x.startswith('S') else 'N')

# %%
np_cut = cut.to_numpy()

# %%
te = TransactionEncoder()
te_ary = te.fit(np_cut).transform(np_cut)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#    @Realty      A   AIME    ASL  Abercromby's    Ace  Airport   Alex  \
# 0    False  False  False  False         False  False    False  False
# 1    False  False  False  False         False  False    False  False
# 2    False  False  False  False         False  False    False  False
# 3    False  False  False  False         False  False    False  False
# 4    False  False  False  False         False  False    False  False
#
#    Alexkarbon  Allan  ...  hockingstuart/Marshall  hockingstuart/Sweeney  \
# 0       False  False  ...                   False                  False
# 1       False  False  ...                   False                  False
# 2       False  False  ...                   False                  False
# 3       False  False  ...                   False                  False
# 4       False  False  ...                   False                  False
#
#    hockingstuart/Village  hockingstuart/hockingstuart  iHomes   iOne  \
# 0                  False                        False   False  False
# 1                  False                        False   False  False
# 2                  False                        False   False  False
# 3                  False                        False   False  False
# 4                  False                        False   False  False
#
#    iProperty  iSell  iTRAK  voglwalpole
# 0      False  False  False        False
# 1      False  False  False        False
# 2      False  False  False        False
# 3      False  False  False        False
# 4      False  False  False        False
#
# [5 rows x 398 columns]

# %%
res = fpgrowth(df, min_support=0.01, use_colnames=True, max_len=3)

# %%
res.head()
# Out:
#     support                 itemsets
# 0  0.757904                      (S)
# 1  0.274201  (Northern Metropolitan)
# 2  0.096345                 (Jellis)
# 3  0.025736                 (Biggin)
# 4  0.242096                      (N)

# %%
res[res['itemsets'].map(len) == 3].sort_values(by=['support'], ascending=False)
# Out:
#      support                                   itemsets
# 47  0.043869         (Northern Metropolitan, S, Nelson)
# 54  0.041516       (Marshall, Southern Metropolitan, S)
# 39  0.036495         (Jellis, S, Southern Metropolitan)
# 87  0.032278         (Buxton, S, Southern Metropolitan)
# 62  0.029150  (hockingstuart, S, Southern Metropolitan)
# 74  0.024101          (S, Northern Metropolitan, Barry)
# 73  0.023039           (Western Metropolitan, S, Barry)
# 37  0.022006         (Jellis, S, Northern Metropolitan)
# 49  0.019998          (Western Metropolitan, S, Nelson)
# 81  0.018563            (S, Northern Metropolitan, Ray)
# 75  0.016555           (Eastern Metropolitan, S, Barry)
# 55  0.014374       (N, Marshall, Southern Metropolitan)
# 38  0.012940         (N, Jellis, Southern Metropolitan)
# 48  0.012251         (N, Nelson, Northern Metropolitan)
# 86  0.011505         (Buxton, N, Southern Metropolitan)
# 63  0.010673   (Western Metropolitan, hockingstuart, S)
# 97  0.010558             (Jas, S, Western Metropolitan)
# 61  0.010530  (hockingstuart, S, Northern Metropolitan)
# 93  0.010185           (Miles, Eastern Metropolitan, S)

# %%
ar = association_rules(res, metric="confidence", min_threshold=0.1)

# %%
ar.head()
# Out:
#                antecedents              consequents  antecedent support  \
# 0                      (S)  (Northern Metropolitan)            0.757904
# 1  (Northern Metropolitan)                      (S)            0.274201
# 2                 (Jellis)                      (S)            0.096345
# 3                 (Jellis)  (Northern Metropolitan)            0.096345
# 4  (Northern Metropolitan)                 (Jellis)            0.274201
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.274201  0.215011    0.283692  1.034612  0.007193    1.013250
# 1            0.757904  0.215011    0.784137  1.034612  0.007193    1.121526
# 2            0.757904  0.071269    0.739726  0.976015 -0.001751    0.930157
# 3            0.274201  0.029064    0.301668  1.100170  0.002646    1.039332
# 4            0.096345  0.029064    0.105996  1.100170  0.002646    1.010795

# %%
ar[(ar['antecedents'].map(len) == 2) | (ar['consequents'].map(len) == 2)].sort_values(by=['confidence'], ascending=False).head(20)
# Out:
#                                 antecedents                consequents  \
# 141                                (Jas, S)     (Western Metropolitan)
# 59                            (N, Marshall)    (Southern Metropolitan)
# 55                            (Marshall, S)    (Southern Metropolitan)
# 135                              (Miles, S)     (Eastern Metropolitan)
# 125                             (Buxton, S)    (Southern Metropolitan)
# 113            (Northern Metropolitan, Ray)                        (S)
# 121                             (Buxton, N)    (Southern Metropolitan)
# 134           (Miles, Eastern Metropolitan)                        (S)
# 142             (Jas, Western Metropolitan)                        (S)
# 143                                   (Jas)  (Western Metropolitan, S)
# 100          (Northern Metropolitan, Barry)                        (S)
# 76    (Western Metropolitan, hockingstuart)                        (S)
# 94            (Western Metropolitan, Barry)                        (S)
# 36          (Northern Metropolitan, Nelson)                        (S)
# 12          (Jellis, Northern Metropolitan)                        (S)
# 73   (hockingstuart, Southern Metropolitan)                        (S)
# 70   (hockingstuart, Northern Metropolitan)                        (S)
# 54        (Marshall, Southern Metropolitan)                        (S)
# 137                                 (Miles)  (Eastern Metropolitan, S)
# 45           (Western Metropolitan, Nelson)                        (S)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 141            0.010587            0.195071  0.010558    0.997290  5.112450
# 59             0.014919            0.339588  0.014374    0.963462  2.837148
# 55             0.043238            0.339588  0.041516    0.960186  2.827502
# 135            0.011190            0.125581  0.010185    0.910256  7.248361
# 125            0.039479            0.339588  0.032278    0.817587  2.407586
# 113            0.022723            0.757904  0.018563    0.816919  1.077866
# 121            0.014116            0.339588  0.011505    0.815041  2.400087
# 134            0.012509            0.757904  0.010185    0.814220  1.074305
# 142            0.013026            0.757904  0.010558    0.810573  1.069492
# 143            0.013083            0.151690  0.010558    0.807018  5.320180
# 100            0.030269            0.757904  0.024101    0.796209  1.050540
# 76             0.013485            0.757904  0.010673    0.791489  1.044313
# 94             0.029408            0.757904  0.023039    0.783415  1.033659
# 36             0.056120            0.757904  0.043869    0.781697  1.031393
# 12             0.029064            0.757904  0.022006    0.757157  0.999014
# 73             0.038503            0.757904  0.029150    0.757079  0.998911
# 70             0.014030            0.757904  0.010530    0.750511  0.990245
# 54             0.055890            0.757904  0.041516    0.742813  0.980088
# 137            0.013714            0.092529  0.010185    0.742678  8.026447
# 45             0.027027            0.757904  0.019998    0.739915  0.976264
#
#      leverage  conviction
# 141  0.008493  297.018850
# 59   0.009308   18.074434
# 55   0.026833   16.587348
# 135  0.008780    9.743526
# 125  0.018871    3.620426
# 113  0.001341    1.322343
# 121  0.006712    3.570579
# 134  0.000704    1.303132
# 142  0.000686    1.278040
# 143  0.008574    4.395789
# 100  0.001159    1.187957
# 76   0.000453    1.161071
# 94   0.000750    1.117784
# 36   0.001335    1.108991
# 12  -0.000022    0.996922
# 73  -0.000032    0.996602
# 70  -0.000104    0.970367
# 54  -0.000843    0.941322
# 137  0.008916    3.526595
# 45  -0.000486    0.930833
